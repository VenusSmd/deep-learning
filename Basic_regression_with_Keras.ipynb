# %% [markdown]
# # **"Regression for Structured Data"**
# This dataset was introduced and published in a 2016 paper titled "2016 House Price Estimation from Visual and Textual Features.
# https://github.com/emanhamed/Houses-dataset
#
# https://arxiv.org/pdf/1609.08399.pdf

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from sklearn.preprocessing import LabelBinarizer
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from keras.optimizers import Adam
import pandas as pd
import numpy as np
import glob
import cv2
import os
import locale

# %%
cols = ["bedrooms", "bathrooms", "area", "zipcode", "price"]

df = pd.read_csv("https://raw.githubusercontent.com/emanhamed/Houses-dataset/master/Houses%20Dataset/HousesInfo.txt", sep=" ", header=None, names=cols)

# %%
df.head(10)
# Out:
#    bedrooms  bathrooms  area  zipcode    price
# 0         4        4.0  4053    85255   869500
# 1         4        3.0  3343    36372   865200
# 2         3        4.0  3923    85266   889000
# 3         5        5.0  4022    85262   910000
# 4         3        4.0  4116    85266   971226
# 5         4        5.0  4581    85266  1249000
# 6         3        4.0  2544    85262   799000
# 7         4        5.0  5524    85266  1698000
# 8         3        4.0  4229    85255  1749000
# 9         4        5.0  3550    85262  1500000

# %%
# number of unique zipcodes
df['zipcode'].nunique()
# Out:
# 49

# %%
zipcode_counts = df['zipcode'].value_counts()

zipcodes = zipcode_counts.index
counts = zipcode_counts.values
# loop over each of the unique zip codes and their corresponding
# count
for (zipcode, count) in zip(zipcodes, counts):
    # the zip code counts for our housing dataset is *extremely*
    # unbalanced (some only having 1 or 2 houses per zip code)
    # removing any houses with less
    # than 25 houses per zip code
    if count < 25:
        idxs = df[df["zipcode"] == zipcode].index
        df.drop(idxs, inplace=True)
df.shape
# Out:
# (362, 5)

# %%
#splitting the dataset into training and testing sets using train_test_split from sklearn.model_selection
(train, test) = train_test_split(df, test_size=0.25, random_state=42)
print(train.shape)
print(test.shape)
# Out:
# (271, 5)
# (91, 5)

# %%
# find the largest house price in the training set and use it to
# scale our house prices to the range [0, 1]
# for a better training and convergence
maxPrice = train["price"].max()
trainY = train["price"] / maxPrice
testY = test["price"] / maxPrice

# %%
# Initialize the LabelBinarizer - for 'zipcode'
zipBinarizer = LabelBinarizer()

# Fit on the training data only
zipBinarizer.fit(train["zipcode"])

# Transform both training and testing data
trainCategorical = zipBinarizer.transform(train["zipcode"])
testCategorical = zipBinarizer.transform(test["zipcode"])

# %%
# Initialize the column names of the continuous data
continuous = ["bedrooms", "bathrooms", "area"]

# Initialize MinMaxScaler
cs = MinMaxScaler()

# Fit on the training data only
cs.fit(train[continuous])

# Transform both training and testing data
trainContinuous = cs.transform(train[continuous])
testContinuous = cs.transform(test[continuous])

# %%
#combine them back into a single dataset for training or testing
trainX = np.hstack([trainCategorical, trainContinuous])
testX = np.hstack([testCategorical, testContinuous])
print(trainX.shape)
print(testX.shape)
# Out:
# (271, 10)
# (91, 10)

# %%
#model architecture
dim = trainX.shape[1]
# define our MLP network
model = Sequential()
model.add(Dense(8, input_dim=dim, activation="relu"))
model.add(Dense(4, activation="relu"))
model.add(Dense(1, activation="linear"))

# %%
#compile model
opt = Adam(learning_rate=1e-3)
model.compile(loss="mean_absolute_percentage_error", optimizer=opt)

200
# 34/34 [==============================] - 0s 2ms/step - loss: 23.0844 - val_loss: 27.6471
# Epoch 66/200
# 34/34 [==============================] - 0s 2ms/step - loss: 23.5313 - val_loss: 25.2686
# Epoch 67/200
# 34/34 [==============================] - 0s 2ms/step - loss: 23.6347 - val_loss: 27.7612
# Epoch 68/200
# 34/34 [==============================] - 0s 2ms/step - loss: 23.2885 - val_loss: 25.8020
# Epoch 69/200
# 34/34 [==============================] - 0s 2ms/step - loss: 22.4411 - val_loss: 29.4693
# Epoch 70/200
# 34/34 [==============================] - 0s 2ms/step - loss: 23.6993 - val_loss: 29.5063
# Epoch 71/200
# 34/34 [==============================] - 0s 2ms/step - loss: 24.2208 - val_loss: 25.9124
# Epoch 72/200
# 34/34 [==============================] - 0s 2ms/step - loss: 22.6396 - val_loss: 26.1552
# Epoch 73/200
# 34/34 [==============================] - 0s 2ms/step - loss: 23.0860 - val_loss: 24.7203
# Epoch 74/200
# 34/34 [==============================] - 0s 2ms/step - loss: 22.3138 - val_loss: 24.9559
# Epoch 75/200
# 34/34 [==============================] - 0s 2ms/step - loss: 21.5822 - val_loss: 24.1765
# Epoch 76/200
# 34/34 [==============================] - 0s 2ms/step - loss: 21.9387 - val_loss: 25.7230
# Epoch 77/200
# 34/34 [==============================] - 0s 2ms/step - loss: 22.7322 - val_loss: 24.3299
# Epoch 78/200
# 34/34 [==============================] - 0s 2ms/step - loss: 22.4988 - val_loss: 25.1138
# Epoch 79/200
# 34/34 [==============================] - 0s 2ms/step - loss: 22.2701 - val_loss: 24.9498
# Epoch 80/200
# 34/34 [==============================] - 0s 2ms/step - loss: 24.9903 - val_loss: 30.5373
# Epoch 81/200
# 34/34 [==============================] - 0s 2ms/step - loss: 22.0116 - val_loss: 25.3305
# Epoch 82/200
# 34/34 [==============================] - 0s 2ms/step - loss: 22.0214 - val_loss: 25.6874
# Epoch 83/200
# 34/34 [==============================] - 0s 2ms/step - loss: 21.7732 - val_loss: 25.5657
# Epoch 84/200
# 34/34 [==============================] - 0s 2ms/step - loss: 23.9998 - val_loss: 25.4326
# Epoch 85/200
# 34/34 [==============================] - 0s 2ms/step - loss: 22.3198 - val_loss: 23.9643
# Epoch 86/200
# 34/34 [==============================] - 0s 2ms/step - loss: 21.9200 - val_loss: 24.9137
# Epoch 87/200
# 34/34 [==============================] - 0s 2ms/step - loss: 21.6853 - val_loss: 24.3978
# Epoch 88/200
# 34/34 [==============================] - 0s 2ms/step - loss: 22.0699 - val_loss: 27.7620
# Epoch 89/200
# 34/34 [==============================] - 0s 2ms/step - loss: 22.9646 - val_loss: 23.5878
# Epoch 90/200
# 34/34 [==============================] - 0s 2ms/step - loss: 21.7132 - val_loss: 23.8589
# Epoch 91/200
# 34/34 [==============================] - 0s 2ms/step - loss: 22.2193 - val_loss: 23.7755
# Epoch 92/200
# 34/34 [==============================] - 0s 2ms/step - loss: 23.8193 - val_loss: 24.5083
# Epoch 93/200
# 34/34 [==============================] - 0s 2ms/step - loss: 22.6111 - val_loss: 23.4120
# Epoch 94/200
# 34/34 [==============================] - 0s 2ms/step - loss: 21.0610 - val_loss: 24.3164
# Epoch 95/200
# 34/34 [==============================] - 0s 2ms/step - loss: 22.3335 - val_loss: 25.8843
# Epoch 96/200
# 34/34 [==============================] - 0s 2ms/step - loss: 22.7799 - val_loss: 24.3934
# Epoch 97/200
# 34/34 [==============================] - 0s 2ms/step - loss: 22.3152 - val_loss: 25.5419
# Epoch 98/200
# 34/34 [==============================] - 0s 2ms/step - loss: 25.6797 - val_loss: 30.0870
# Epoch 99/200
# 34/34 [==============================] - 0s 2ms/step - loss: 21.5385 - val_loss: 25.3295
# Epoch 100/200
# 34/34 [==============================] - 0s 2ms/step - loss: 21.5975 - val_loss: 25.2191
# Epoch 101/200
# 34/34 [==============================] - 0s 2ms/step - loss: 23.1304 - val_loss: 23.6544
# Epoch 102/200
# 34/34 [==============================] - 0s 2ms/step - loss: 22.8289 - val_loss: 23.8083
# Epoch 103/200
# 34/34 [==============================] - 0s 2ms/step - loss: 23.9360 - val_loss: 24.6436
# Epoch 104/200
# 34/34 [==============================] - 0s 2ms/step - loss: 23.9108 - val_loss: 24.2123
# Epoch 105/200
# 34/34 [==============================] - 0s 3ms/step - loss: 22.3339 - val_loss: 24.0860
# Epoch 106/200
# 34/34 [==============================] - 0s 3ms/step - loss: 22.1104 - val_loss: 23.5206
# Epoch 107/200
# 34/34 [==============================] - 0s 2ms/step - loss: 21.0229 - val_loss: 23.9440
# Epoch 108/200
# 34/34 [==============================] - 0s 3ms/step - loss: 21.6570 - val_loss: 23.0588
# Epoch 109/200
# 34/34 [==============================] - 0s 2ms/step - loss: 22.2203 - val_loss: 23.7508
# Epoch 110/200
# 34/34 [==============================] - 0s 2ms/step - loss: 22.0818 - val_loss: 24.7201
# Epoch 111/200
# 34/34 [==============================] - 0s 2ms/step - loss: 21.2941 - val_loss: 24.5330
# Epoch 112/200
# 34/34 [==============================] - 0s 3ms/step - loss: 20.8628 - val_loss: 23.6419
# Epoch 113/200
# 34/34 [==============================] - 0s 2ms/step - loss: 22.3316 - val_loss: 30.9660
# Epoch 114/200
# 34/34 [==============================] - 0s 3ms/step - loss: 22.4617 - val_loss: 25.4084
# Epoch 115/200
# 34/34 [==============================] - 0s 3ms/step - loss: 22.1543 - val_loss: 27.6697
# Epoch 116/200
# 34/34 [==============================] - 0s 3ms/step - loss: 23.1002 - val_loss: 25.2145
# Epoch 117/200
# 34/34 [==============================] - 0s 3ms/step - loss: 21.4748 - val_loss: 25.0250
# Epoch 118/200
# 34/34 [==============================] - 0s 2ms/step - loss: 21.1700 - val_loss: 24.8861
# Epoch 119/200
# 34/34 [==============================] - 0s 2ms/step - loss: 21.3124 - val_loss: 23.6690
# Epoch 120/200
# 34/34 [==============================] - 0s 2ms/step - loss: 21.1414 - val_loss: 25.4425
# Epoch 121/200
# 34/34 [==============================] - 0s 2ms/step - loss: 23.2278 - val_loss: 24.0115
# Epoch 122/200
# 34/34 [==============================] - 0s 2ms/step - loss: 21.9445 - val_loss: 27.2754
# Epoch 123/200
# 34/34 [==============================] - 0s 2ms/step - loss: 20.5591 - val_loss: 22.4733
# Epoch 124/200
# 34/34 [==============================] - 0s 2ms/step - loss: 20.4882 - val_loss: 24.6038
# Epoch 125/200
# 34/34 [==============================] - 0s 2ms/step - loss: 22.6207 - val_loss: 23.8655
# Epoch 126/200
# 34/34 [==============================] - 0s 2ms/step - loss: 22.8401 - val_loss: 23.9818
# Epoch 127/200
# 34/34 [==============================] - 0s 2ms/step - loss: 21.4913 - val_loss: 24.0284
# Epoch 128/200
# 34/34 [==============================] - 0s 2ms/step - loss: 20.2271 - val_loss: 22.9502
# Epoch 129/200
# 34/34 [==============================] - 0s 2ms/step - loss: 22.0644 - val_loss: 22.7146
# Epoch 130/200
# 34/34 [==============================] - 0s 2ms/step - loss: 22.8247 - val_loss: 23.9275
# Epoch 131/200
# 34/34 [==============================] - 0s 2ms/step - loss: 22.9862 - val_loss: 22.6998
# Epoch 132/200
# 34/34 [==============================] - 0s 2ms/step - loss: 22.5326 - val_loss: 24.6628
# Epoch 133/200
# 34/34 [==============================] - 0s 2ms/step - loss: 23.4766 - val_loss: 25.1387
# Epoch 134/200
# 34/34 [==============================] - 0s 2ms/step - loss: 23.2581 - val_loss: 23.3690
# Epoch 135/200
# 34/34 [==============================] - 0s 2ms/step - loss: 20.3324 - val_loss: 23.6966
# Epoch 136/200
# 34/34 [==============================] - 0s 2ms/step - loss: 21.6042 - val_loss: 28.9124
# Epoch 137/200
# 34/34 [==============================] - 0s 2ms/step - loss: 22.7268 - val_loss: 24.1284
# Epoch 138/200
# 34/34 [==============================] - 0s 2ms/step - loss: 21.0056 - val_loss: 24.0501
# Epoch 139/200
# 34/34 [==============================] - 0s 2ms/step - loss: 21.8220 - val_loss: 22.7986
# Epoch 140/200
# 34/34 [==============================] - 0s 2ms/step - loss: 21.3699 - val_loss: 23.5270
# Epoch 141/200
# 34/34 [==============================] - 0s 2ms/step - loss: 20.0042 - val_loss: 26.0839
# Epoch 142/200
# 34/34 [==============================] - 0s 2ms/step - loss: 22.1256 - val_loss: 22.3187
# Epoch 143/200
# 34/34 [==============================] - 0s 2ms/step - loss: 23.8493 - val_loss: 26.2417
# Epoch 144/200
# 34/34 [==============================] - 0s 2ms/step - loss: 20.6917 - val_loss: 24.0699
# Epoch 145/200
# 34/34 [==============================] - 0s 2ms/step - loss: 21.4869 - val_loss: 24.0741
# Epoch 146/200
# 34/34 [==============================] - 0s 2ms/step - loss: 21.1257 - val_loss: 24.2090
# Epoch 147/200
# 34/34 [==============================] - 0s 2ms/step - loss: 20.7793 - val_loss: 22.8806
# Epoch 148/200
# 34/34 [==============================] - 0s 2ms/step - loss: 21.1694 - val_loss: 24.1957
# Epoch 149/200
# 34/34 [==============================] - 0s 2ms/step - loss: 21.0029 - val_loss: 24.0510
# Epoch 150/200
# 34/34 [==============================] - 0s 2ms/step - loss: 20.8757 - val_loss: 23.7508
# Epoch 151/200
# 34/34 [==============================] - 0s 2ms/step - loss: 20.1349 - val_loss: 23.9858
# Epoch 152/200
# 34/34 [==============================] - 0s 2ms/step - loss: 20.9418 - val_loss: 23.9187
# Epoch 153/200
# 34/34 [==============================] - 0s 2ms/step - loss: 21.6975 - val_loss: 27.7615
# Epoch 154/200
# 34/34 [==============================] - 0s 2ms/step - loss: 21.3039 - val_loss: 26.9528
# Epoch 155/200
# 34/34 [==============================] - 0s 2ms/step - loss: 20.7595 - val_loss: 22.9855
# Epoch 156/200
# 34/34 [==============================] - 0s 2ms/step - loss: 20.9149 - val_loss: 23.4425
# Epoch 157/200
# 34/34 [==============================] - 0s 2ms/step - loss: 21.0805 - val_loss: 26.4645
# Epoch 158/200
# 34/34 [==============================] - 0s 2ms/step - loss: 21.4370 - val_loss: 24.8311
# Epoch 159/200
# 34/34 [==============================] - 0s 2ms/step - loss: 20.8813 - val_loss: 25.4960
# Epoch 160/200
# 34/34 [==============================] - 0s 2ms/step - loss: 20.9713 - val_loss: 26.0064
# Epoch 161/200
# 34/34 [==============================] - 0s 2ms/step - loss: 21.5115 - val_loss: 24.5903
# Epoch 162/200
# 34/34 [==============================] - 0s 2ms/step - loss: 20.6415 - val_loss: 22.3839
# Epoch 163/200
# 34/34 [==============================] - 0s 2ms/step - loss: 20.3699 - val_loss: 22.6477
# Epoch 164/200
# 34/34 [==============================] - 0s 2ms/step - loss: 20.0186 - val_loss: 23.6549
# Epoch 165/200
# 34/34 [==============================] - 0s 2ms/step - loss: 20.1467 - val_loss: 25.9245
# Epoch 166/200
# 34/34 [==============================] - 0s 2ms/step - loss: 22.3418 - val_loss: 23.6179
# Epoch 167/200
# 34/34 [==============================] - 0s 2ms/step - loss: 21.5900 - val_loss: 23.7300
# Epoch 168/200
# 34/34 [==============================] - 0s 2ms/step - loss: 21.0799 - val_loss: 23.5303
# Epoch 169/200
# 34/34 [==============================] - 0s 2ms/step - loss: 21.2934 - val_loss: 22.6598
# Epoch 170/200
# 34/34 [==============================] - 0s 2ms/step - loss: 23.5781 - val_loss: 24.4232
# Epoch 171/200
# 34/34 [==============================] - 0s 2ms/step - loss: 21.3053 - val_loss: 23.1693
# Epoch 172/200
# 34/34 [==============================] - 0s 2ms/step - loss: 21.9555 - val_loss: 23.6700
# Epoch 173/200
# 34/34 [==============================] - 0s 2ms/step - loss: 20.5968 - val_loss: 23.2606
# Epoch 174/200
# 34/34 [==============================] - 0s 2ms/step - loss: 21.7224 - val_loss: 24.9114
# Epoch 175/200
# 34/34 [==============================] - 0s 2ms/step - loss: 20.5793 - val_loss: 22.7157
# Epoch 176/200
# 34/34 [==============================] - 0s 2ms/step - loss: 21.1869 - val_loss: 22.6899
# Epoch 177/200
# 34/34 [==============================] - 0s 2ms/step - loss: 20.1451 - val_loss: 25.6014
# Epoch 178/200
# 34/34 [==============================] - 0s 2ms/step - loss: 20.2591 - val_loss: 25.4759
# Epoch 179/200
# 34/34 [==============================] - 0s 2ms/step - loss: 19.6435 - val_loss: 23.2638
# Epoch 180/200
# 34/34 [==============================] - 0s 2ms/step - loss: 20.9333 - val_loss: 24.9191
# Epoch 181/200
# 34/34 [==============================] - 0s 2ms/step - loss: 20.6894 - val_loss: 24.0994
# Epoch 182/200
# 34/34 [==============================] - 0s 2ms/step - loss: 25.2101 - val_loss: 22.6607
# Epoch 183/200
# 34/34 [==============================] - 0s 2ms/step - loss: 21.1638 - val_loss: 24.4323
# Epoch 184/200
# 34/34 [==============================] - 0s 2ms/step - loss: 21.4850 - val_loss: 23.5090
# Epoch 185/200
# 34/34 [==============================] - 0s 2ms/step - loss: 20.5738 - val_loss: 22.7422
# Epoch 186/200
# 34/34 [==============================] - 0s 2ms/step - loss: 22.4381 - val_loss: 23.9340
# Epoch 187/200
# 34/34 [==============================] - 0s 2ms/step - loss: 20.5856 - val_loss: 25.5272
# Epoch 188/200
# 34/34 [==============================] - 0s 2ms/step - loss: 22.0105 - val_loss: 23.5942
# Epoch 189/200
# 34/34 [==============================] - 0s 2ms/step - loss: 20.5656 - val_loss: 25.1085
# Epoch 190/200
# 34/34 [==============================] - 0s 2ms/step - loss: 20.9281 - val_loss: 24.0895
# Epoch 191/200
# 34/34 [==============================] - 0s 2ms/step - loss: 19.8311 - val_loss: 24.1980
# Epoch 192/200
# 34/34 [==============================] - 0s 2ms/step - loss: 21.2471 - val_loss: 27.0832
# Epoch 193/200
# 34/34 [==============================] - 0s 2ms/step - loss: 21.1206 - val_loss: 22.9681
# Epoch 194/200
# 34/34 [==============================] - 0s 2ms/step - loss: 20.1070 - val_loss: 24.8126
# Epoch 195/200
# 34/34 [==============================] - 0s 2ms/step - loss: 21.6159 - val_loss: 22.9763
# Epoch 196/200
# 34/34 [==============================] - 0s 2ms/step - loss: 20.7225 - val_loss: 22.8408
# Epoch 197/200
# 34/34 [==============================] - 0s 2ms/step - loss: 20.4169 - val_loss: 22.4667
# Epoch 198/200
# 34/34 [==============================] - 0s 2ms/step - loss: 20.2415 - val_loss: 23.2635
# Epoch 199/200
# 34/34 [==============================] - 0s 2ms/step - loss: 20.9070 - val_loss: 24.3503
# Epoch 200/200
# 34/34 [==============================] - 0s 2ms/step - loss: 20.0457 - val_loss: 22.8998

# %%
preds = model.predict(testX)
# Out:
# 3/3 [==============================] - 0s 2ms/step

# %%
# Model Evaluation Process
# 1. Making Predictions:
#    - The model is used to predict house prices on the testing dataset (testX).
#    - Predictions are generated based on the input features of the test set.
preds = model.predict(testX)

# 2. Error Calculation:
#    - The difference between predicted and actual house prices (testY) is calculated.
#    - Both the percentage difference and the absolute percentage difference are computed to assess the model's accuracy and error distribution.

diff = preds.flatten() - testY
percentDiff = (diff / testY) * 100
absPercentDiff = np.abs(percentDiff)


# 3. Statistical Summary of Prediction Errors:
#    - The mean and standard deviation of the absolute percentage differences are computed.
#    - These statistics provide insights into the average error margin of the model's predictions and the variability of these errors across the test dataset.
mean = np.mean(absPercentDiff)
std = np.std(absPercentDiff)


# 4. Displaying Dataset and Model Performance Statistics:
#    - Average and standard deviation of actual house prices in the dataset are displayed, formatted as currency for better readability.
#    - The mean absolute percentage error (MAPE) and its standard deviation are also shown, providing a quantitative measure of the model's prediction accuracy and consistency.
#    - The computation assumes no zero values in testY to avoid division by zero errors.


print("avg. house price: {}, std house price: {}".format(
    locale.currency(df["price"].mean(), grouping=True),
    locale.currency(df["price"].std(), grouping=True)))
print("mean: {:.2f}%, std: {:.2f}%".format(mean, std))
# Out:
# 3/3 [==============================] - 0s 2ms/step
# avg. house price: $533,388.27, std house price: $493,403.08
# mean: 22.90%, std: 21.57%
